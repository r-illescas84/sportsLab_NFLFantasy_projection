# %% [markdown]
# # Obtaining general stats

# %% [markdown]
# ### Libraries

# %%
import nfl_data_py as nfl
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
py_players = nfl.import_players()

# %% [markdown]
# ### Preparing data

# %% [markdown]
# Defining parameters for functions

# %%
year = 2019
filename = f"fp_original_files/FantasyPros_{year}_Overall_ADP_Rankings.csv"
separator = ","

# %% [markdown]
# Reading csv with Fantasy Pros' ADP

# %%
adp = pd.read_csv(filename, sep=separator)
print(f"Total players on csv file: {len(adp)}.")
print(adp.head())
# Out:
# Total players on csv file: 1046.
#    Rank               Player Team  Bye  POS  ESPN  Sleeper  NFL  RTSports  \
# 0     1       Saquon Barkley  PHI   10  RB1   1.0      NaN  1.0       1.0
# 1     2  Christian McCaffrey   SF    4  RB2   2.0      NaN  3.0       2.0
# 2     3         Alvin Kamara   NO    9  RB3   3.0      NaN  2.0       3.0
# 3     4      Ezekiel Elliott  NaN  NaN  RB4   4.0      NaN  4.0       4.0
# 4     5      DeAndre Hopkins  BAL    8  WR1   5.0      NaN  5.0       6.0
#
#    FFC  Fantrax  AVG
# 0  NaN      1.0    1
# 1  NaN      2.0  2.5
# 2  NaN      3.0  2.5
# 3  NaN      4.0    4
# 4  NaN      6.0  5.3

# %% [markdown]
# Adding gsis_id to players without a problem

# %%
def get_gsis_id(py_players, player_name):
    player = py_players[py_players['display_name']==player_name]
    if player.empty:
        return "--"
    elif len(player)==1:
        return player['gsis_id'].values[0]
    else:
        return "--"
    
adp['gsis_id'] = adp.apply(
    lambda row: get_gsis_id(py_players, row['Player']),
    axis=1
)
adp.to_csv(f"adp_{year}_pre_manual.csv")
empties = adp[adp['gsis_id']=='--']
print(f"Players with no gsis_id found:{len(empties)}. First ten players: ")
print(empties.head(10))
# Out:
# Players with no gsis_id found:187. First ten players:
#     Rank              Player Team  Bye   POS  ESPN  Sleeper   NFL  RTSports  \
# 5      6       David Johnson  NaN  NaN   RB5   6.0      NaN   8.0       7.0
# 10    11      Michael Thomas  NaN  NaN   WR4   8.0      NaN  11.0      14.0
# 19    20  Patrick Mahomes II   KC   12   QB1  18.0      NaN  14.0      22.0
# 20    21       Antonio Brown  NaN  NaN   WR8  21.0      NaN  19.0      21.0
# 21    22          Mike Evans   TB    7   WR9  22.0      NaN  21.0      20.0
# 31    32     Aaron Jones Sr.  MIN   12  RB15  36.0      NaN  36.0      31.0
# 35    36       Chris Carson   NaN  NaN  RB18  34.0      NaN  47.0      32.0
# 39    40        Robert Woods  PIT    7  WR17  39.0      NaN  37.0      50.0
# 44    45         Mark Ingram   II  NaN  RB22  42.0      NaN  50.0      43.0
# 51    52         James White  NaN  NaN  RB25  54.0      NaN  63.0      49.0
#
#     FFC  Fantrax   AVG gsis_id
# 5   NaN      5.0   6.7      --
# 10  NaN     10.0  10.7      --
# 19  NaN     20.0  18.8      --
# 20  NaN     21.0    21      --
# 21  NaN     22.0  21.2      --
# 31  NaN     31.0  32.3      --
# 35  NaN     43.0  36.5      --
# 39  NaN     39.0  41.8      --
# 44  NaN     46.0  44.5      --
# 51  NaN     51.0  53.3      --

# %% [markdown]
# #### Start filling missing players manually

# %% [markdown]
# Printing players with the same name to pick which gsis_id to use. ¡¡¡ Edit the file named adp_{year}_pre_manuel.csv !!!!

# %%
empties_exp = empties[['Player', 'gsis_id']]
for pla in list(empties_exp['Player']):
    jug = py_players[py_players['display_name']==pla]
    if jug.empty:
        pass
    else:
        for i in range(len(jug)):
            nombre = jug['display_name'].values[i]
            pos =jug['position'].values[i]
            rs = jug['rookie_season'].values[i]
            dp = jug['draft_pick'].values[i]
            gsis = jug['gsis_id'].values[i]
            print(f"{nombre}: position ({pos}), rookie season ({rs}) and pick ({dp}). gsis_id: {gsis}")
# Out:
# David Johnson: position (TE), rookie season (2009) and pick (241.0). gsis_id: 00-0026957
# David Johnson: position (RB), rookie season (2015) and pick (86.0). gsis_id: 00-0032187
# Michael Thomas: position (DB), rookie season (2012) and pick (nan). gsis_id: 00-0028908
# Michael Thomas: position (WR), rookie season (2016) and pick (47.0). gsis_id: 00-0032765
# Antonio Brown: position (WR), rookie season (2003) and pick (nan). gsis_id: 00-0021425
# Antonio Brown: position (WR), rookie season (2010) and pick (195.0). gsis_id: 00-0027793
# Mike Evans: position (DT), rookie season (1992) and pick (101.0). gsis_id: 00-0004999
# Mike Evans: position (WR), rookie season (2014) and pick (7.0). gsis_id: 00-0031408
# Robert Woods: position (WR), rookie season (2013) and pick (41.0). gsis_id: 00-0030431
# Robert Woods: position (WR), rookie season (1978) and pick (134.0). gsis_id: WOO568269
# Robert Woods: position (OT), rookie season (1974) and pick (nan). gsis_id: WOO582840
# Mark Ingram: position (WR), rookie season (1987) and pick (28.0). gsis_id: 00-0008024
# Mark Ingram: position (RB), rookie season (2011) and pick (28.0). gsis_id: 00-0027966
# James White: position (RB), rookie season (2014) and pick (130.0). gsis_id: 00-0031062
# James White: position (OT), rookie season (1985) and pick (nan). gsis_id: WHI242632
# James White: position (NT), rookie season (1976) and pick (25.0). gsis_id: WHI264562
# Mike Williams: position (DB), rookie season (1995) and pick (nan). gsis_id: 00-0017884
# Mike Williams: position (WR), rookie season (1989) and pick (269.0). gsis_id: 00-0017890
# Mike Williams: position (G), rookie season (2002) and pick (4.0). gsis_id: 00-0021142
# Mike Williams: position (WR), rookie season (2005) and pick (10.0). gsis_id: 00-0023452
# Mike Williams: position (WR), rookie season (2010) and pick (101.0). gsis_id: 00-0027702
# Mike Williams: position (WR), rookie season (2017) and pick (7.0). gsis_id: 00-0033536
# Mike Williams: position (TE), rookie season (1982) and pick (133.0). gsis_id: WIL439416
# Mike Williams: position (FB), rookie season (1979) and pick (195.0). gsis_id: WIL442647
# Mike Williams: position (DB), rookie season (1975) and pick (22.0). gsis_id: WIL453955
# Lamar Jackson: position (QB), rookie season (2018) and pick (32.0). gsis_id: 00-0034796
# Lamar Jackson: position (CB), rookie season (2020) and pick (nan). gsis_id: 00-0036152
# James Washington: position (S), rookie season (1988) and pick (137.0). gsis_id: 00-0017247
# James Washington: position (WR), rookie season (2018) and pick (60.0). gsis_id: 00-0034676
# Adrian Peterson: position (RB), rookie season (2002) and pick (199.0). gsis_id: 00-0021306
# Adrian Peterson: position (RB), rookie season (2007) and pick (7.0). gsis_id: 00-0025394
# Justin Jackson: position (LB), rookie season (2014) and pick (nan). gsis_id: 00-0030724
# Justin Jackson: position (RB), rookie season (2018) and pick (251.0). gsis_id: 00-0034440
# Anthony Miller: position (TE), rookie season (2012) and pick (nan). gsis_id: 00-0028889
# Anthony Miller: position (WR), rookie season (2018) and pick (51.0). gsis_id: 00-0034353
# Anthony Miller: position (WR), rookie season (1988) and pick (15.0). gsis_id: 00-0011233
# Josh Allen: position (C), rookie season (2014) and pick (nan). gsis_id: 00-0030833
# Josh Allen: position (QB), rookie season (2018) and pick (7.0). gsis_id: 00-0034857
# Chris Thompson: position (DB), rookie season (2004) and pick (150.0). gsis_id: 00-0022877
# Chris Thompson: position (RB), rookie season (2013) and pick (154.0). gsis_id: 00-0030404
# Chris Thompson: position (WR), rookie season (2017) and pick (nan). gsis_id: 00-0033855
# Mike Davis: position (CB), rookie season (1994) and pick (119.0). gsis_id: 00-0004017
# Mike Davis: position (DB), rookie season (1978) and pick (35.0). gsis_id: DAV561150
# Mike Davis: position (RB), rookie season (2015) and pick (126.0). gsis_id: 00-0032063
# David Moore: position (WR), rookie season (2017) and pick (226.0). gsis_id: 00-0033589
# David Moore: position (G), rookie season (2021) and pick (nan). gsis_id: 00-0036486
# Matt Gay: position (K), rookie season (2019) and pick (145.0). gsis_id: 00-0035269
# Matt Gay: position (SAF), rookie season (1994) and pick (nan). gsis_id: 00-0005840
# Jesse James: position (C), rookie season (1995) and pick (62.0). gsis_id: 00-0008246
# Jesse James: position (TE), rookie season (2015) and pick (160.0). gsis_id: 00-0032135
# Brandon Marshall: position (WR), rookie season (2006) and pick (119.0). gsis_id: 00-0024334
# Brandon Marshall: position (ILB), rookie season (2012) and pick (142.0). gsis_id: 00-0029620
# Mike Thomas: position (RB), rookie season (1975) and pick (108.0). gsis_id: THO303100
# Mike Thomas: position (WR), rookie season (2009) and pick (107.0). gsis_id: 00-0027076
# Mike Thomas: position (WR), rookie season (2016) and pick (206.0). gsis_id: 00-0033114
# Anthony Johnson: position (RB), rookie season (1990) and pick (36.0). gsis_id: 00-0008430
# Anthony Johnson: position (DE), rookie season (2014) and pick (nan). gsis_id: 00-0030864
# Anthony Johnson: position (WR), rookie season (2019) and pick (nan). gsis_id: 00-0035474
# Anthony Johnson: position (CB), rookie season (2023) and pick (nan). gsis_id: 00-0038907
# J.J. Jones: position (WR), rookie season (2018) and pick (nan). gsis_id: 00-0034560
# J.J. Jones: position (LB), rookie season (2002) and pick (nan). gsis_id: 00-0020057
# Doug Martin: position (RB), rookie season (2012) and pick (31.0). gsis_id: 00-0029613
# Doug Martin: position (DE), rookie season (1980) and pick (9.0). gsis_id: MAR582118
# Chris Johnson: position (LB), rookie season (2010) and pick (nan). gsis_id: 00-0027637
# Chris Johnson: position (SAF), rookie season (1996) and pick (nan). gsis_id: 00-0008456
# Chris Johnson: position (DB), rookie season (2003) and pick (nan). gsis_id: 00-0021949
# Chris Johnson: position (RB), rookie season (2008) and pick (24.0). gsis_id: 00-0026164
# Chris Johnson: position (SAF), rookie season (2019) and pick (nan). gsis_id: 00-0035456
# Chris Johnson: position (DB), rookie season (1987) and pick (nan). gsis_id: JOH131139
# Matt Jones: position (LB), rookie season (2025) and pick (nan). gsis_id: 00-0040485
# Matt Jones: position (WR), rookie season (2005) and pick (21.0). gsis_id: 00-0023456
# Matt Jones: position (RB), rookie season (2015) and pick (95.0). gsis_id: 00-0031939
# Devin Smith: position (DB), rookie season (2013) and pick (nan). gsis_id: 00-0030203
# Devin Smith: position (WR), rookie season (2015) and pick (37.0). gsis_id: 00-0031934
# Kevin White: position (WR), rookie season (2015) and pick (nan). gsis_id: 00-0031545
# Kevin White: position (CB), rookie season (2015) and pick (nan). gsis_id: 00-0031683
# Justin Watson: position (RB), rookie season (1999) and pick (nan). gsis_id: 00-0017303
# Justin Watson: position (WR), rookie season (2018) and pick (144.0). gsis_id: 00-0034386
# Jonathan Stewart: position (RB), rookie season (2008) and pick (13.0). gsis_id: 00-0026153
# Jonathan Stewart: position (ILB), rookie season (2013) and pick (nan). gsis_id: 00-0029880
# Josh Johnson: position (RB), rookie season (2021) and pick (nan). gsis_id: 00-0036799
# Josh Johnson: position (WR), rookie season (2022) and pick (nan). gsis_id: 00-0037442
# Josh Johnson: position (QB), rookie season (2008) and pick (nan). gsis_id: 00-0026300
# Josh Johnson: position (CB), rookie season (2016) and pick (nan). gsis_id: 00-0030322
# LeShun Daniels: position (G), rookie season (1997) and pick (nan). gsis_id: 00-0003871
# LeShun Daniels: position (RB), rookie season (2017) and pick (nan). gsis_id: 00-0033384
# Chris Warren: position (RB), rookie season (1990) and pick (89.0). gsis_id: 00-0017209
# Chris Warren: position (RB), rookie season (2018) and pick (nan). gsis_id: 00-0034315
# Joe Williams: position (RB), rookie season (2017) and pick (nan). gsis_id: 00-0033286
# Joe Williams: position (LB), rookie season (1987) and pick (nan). gsis_id: WIL384570
# Marcus Johnson: position (G), rookie season (2005) and pick (49.0). gsis_id: 00-0023484
# Marcus Johnson: position (WR), rookie season (2016) and pick (nan). gsis_id: 00-0032980
# Mike White: position (DT), rookie season (1979) and pick (84.0). gsis_id: WHI270628
# Mike White: position (QB), rookie season (2018) and pick (171.0). gsis_id: 00-0034401
# Malcolm Johnson: position (WR), rookie season (1999) and pick (166.0). gsis_id: 00-0008575
# Malcolm Johnson: position (RB), rookie season (2015) and pick (195.0). gsis_id: 00-0032068
# Sam Rogers: position (OLB), rookie season (1994) and pick (64.0). gsis_id: 00-0013979
# Sam Rogers: position (FB), rookie season (2017) and pick (206.0). gsis_id: 00-0033967
# Austin Davis: position (QB), rookie season (2012) and pick (nan). gsis_id: 00-0028957
# Austin Davis: position (C), rookie season (2018) and pick (nan). gsis_id: 00-0034178
# Keith Smith: position (FB), rookie season (2014) and pick (nan). gsis_id: 00-0030968
# Keith Smith: position (DB), rookie season (2004) and pick (73.0). gsis_id: 00-0022851
# Duke Williams: position (WR), rookie season (2019) and pick (nan). gsis_id: 00-0032945
# Duke Williams: position (S), rookie season (2013) and pick (105.0). gsis_id: 00-0030073
# Charles Johnson: position (WR), rookie season (1994) and pick (17.0). gsis_id: 00-0008454
# Charles Johnson: position (DE), rookie season (2007) and pick (83.0). gsis_id: 00-0025470
# Charles Johnson: position (CB), rookie season (1979) and pick (nan). gsis_id: JOH111711
# Charles Johnson: position (NT), rookie season (1979) and pick (nan). gsis_id: JOH116568
# Taiwan Jones: position (RB), rookie season (2011) and pick (125.0). gsis_id: 00-0028063
# Taiwan Jones: position (LB), rookie season (2015) and pick (nan). gsis_id: 00-0031862
# Chad Williams: position (DB), rookie season (2002) and pick (209.0). gsis_id: 00-0021316
# Chad Williams: position (WR), rookie season (2017) and pick (98.0). gsis_id: 00-0033933
# David Williams: position (OT), rookie season (1989) and pick (23.0). gsis_id: 00-0017769
# David Williams: position (WR), rookie season (1986) and pick (82.0). gsis_id: WIL213246
# Marcus Green: position (DT), rookie season (2006) and pick (nan). gsis_id: 00-0023795
# Marcus Green: position (WR), rookie season (2019) and pick (203.0). gsis_id: 00-0035296
# James Williams: position (WR), rookie season (2000) and pick (175.0). gsis_id: 00-0019491
# James Williams: position (OT), rookie season (2010) and pick (nan). gsis_id: 00-0027452
# James Williams: position (LB), rookie season (2024) and pick (242.0). gsis_id: 00-0039430
# James Williams: position (DB), rookie season (1990) and pick (nan). gsis_id: WIL331782
# Nick Williams: position (DT), rookie season (2013) and pick (nan). gsis_id: 00-0030500
# Nick Williams: position (WR), rookie season (2013) and pick (nan). gsis_id: 00-0029848
# Ryan Griffin: position (QB), rookie season (2013) and pick (nan). gsis_id: 00-0029857
# Ryan Griffin: position (TE), rookie season (2013) and pick (nan). gsis_id: 00-0030108
# Ryan Grant: position (RB), rookie season (2006) and pick (nan). gsis_id: 00-0022984
# Ryan Grant: position (WR), rookie season (2014) and pick (142.0). gsis_id: 00-0031068
# Brandon Williams: position (CB), rookie season (2003) and pick (nan). gsis_id: 00-0021878
# Brandon Williams: position (WR), rookie season (2006) and pick (84.0). gsis_id: 00-0024299
# Brandon Williams: position (LB), rookie season (2009) and pick (nan). gsis_id: 00-0027087
# Brandon Williams: position (TE), rookie season (2013) and pick (nan). gsis_id: 00-0029793
# Brandon Williams: position (DE), rookie season (2013) and pick (nan). gsis_id: 00-0030511
# Brandon Williams: position (CB), rookie season (2016) and pick (92.0). gsis_id: 00-0032769
# Brandon Coleman: position (WR), rookie season (2014) and pick (nan). gsis_id: 00-0030801
# Brandon Coleman: position (OT), rookie season (2024) and pick (67.0). gsis_id: 00-0039913
# Carlos Henderson: position (WR), rookie season (2017) and pick (nan). gsis_id: 00-0033919
# Carlos Henderson: position (DB), rookie season (1987) and pick (nan). gsis_id: HEN047013
# James Wright: position (WR), rookie season (2014) and pick (239.0). gsis_id: 00-0031291
# James Wright: position (TE), rookie season (1978) and pick (179.0). gsis_id: WRI384285
# Rod Smith: position (WR), rookie season (1995) and pick (nan). gsis_id: 00-0015290
# Rod Smith: position (RB), rookie season (2015) and pick (nan). gsis_id: 00-0031900
# Rod Smith: position (DB), rookie season (1992) and pick (35.0). gsis_id: 00-0015289

# %% [markdown]
# Looking for players one by one

# %%
specific_player = py_players[ py_players['display_name'].str.lower().str.contains('.*gary.*jennings.*')]
print(specific_player[['display_name', 'gsis_id','position','rookie_season','birth_date']])
# Out:
#         display_name     gsis_id position  rookie_season  birth_date
# 11026  Gary Jennings  00-0035589       WR           2019  1997-03-07

# %% [markdown]
# ### Adding stats to the filled file

# %% [markdown]
# Position and season

# %%
adp_full = pd.read_csv(f"adp_{year}_pre_manual.csv")
def get_pos(py_players, player_id):
    player = py_players[py_players['gsis_id']==player_id]
    if player.empty:
        return "D/ST"
    elif len(player)==1:
        return player['position'].values[0]
    else:
        return "--"
    
adp_full['position'] = adp_full.apply(
    lambda row: get_pos(py_players, row['gsis_id']),
    axis=1
)

adp_full['season'] = year-1

# %% [markdown]
# Availability

# %%
def get_availability(rost, injs, players, player_id, max_year):
    if max_year >= datetime.now().year or max_year < 2009:
        print(f"ERROR: max_year({max_year}) has to be the last completed season or higher than 2009.")
        return "--"
    # Get years played
    player_info = players[players['gsis_id'] == player_id]
    if player_info.empty:
        print(f"ERROR: Player {player_id} not found.")
        return "--"
    player_name = player_info['display_name'].values[0]
    first_year = player_info['rookie_season'].values[0]
    first_year = max(first_year, 2009)
    if first_year > max_year: 
        print(f"ERROR: Player {player_id} first year ({first_year}) is before max_year ({max_year}).")
        return "--"
    #print("\tPlayer last season: ", player_info['last_season'].values[0])
    last_year = player_info['last_season'].values[0]
    if last_year < 2009:
        print(f"ERROR: Player {player_id} last year ({first_year}) is before 2009 so there is no data available.")
        return "--"
    last_year = min(last_year, max_year)
    years = list(range(first_year, last_year + 1))

    # Get games rostered and games active
    weekly_rosters = rost[rost['season'].isin(years)]
    player_weekly = weekly_rosters[weekly_rosters['player_id'] == player_id]
    player_weekly = player_weekly[player_weekly['week'] <= 18]
    player_weekly = player_weekly[((player_weekly['season'] <= 2020) & (player_weekly['week'] <= 17)) | (player_weekly['season'] > 2020)]
    status_inactive = ['EXE', 'INA', 'PUP', 'RES', 'RSN', 'RSR', 'SUS']
    not_on_team = ['DEV', 'CUT', 'NWT', 'RET', 'RFA', 'TRC', 'TRD', 'TRL', 'TRT', 'UFA', 'E14']
    status_active = ['ACT']
    games_missed = player_weekly[player_weekly['status'].isin(status_inactive)]
    games_available = player_weekly[player_weekly['status'].isin(status_inactive + status_active)]
    n_games_available = len(games_available)
    games_played = player_weekly[player_weekly['status'].isin(status_active)]
    n_games_played = len(games_played)

    # Missed due to coach decision
    injuries = injs[injs['season'].isin(years)]
    not_injured = ['Coaching', "Coach's decision", 'Coaching Decision ', "Coach's Decision", "Not injury related - coach's decision",
                   'Not injury related - personal matter', 'personal matter', 'Ankle [Not Injury Related - Personal, Thursday Only]',
                   'Not injury related - resting player']
    player_injuries = injuries[injuries['gsis_id'] == player_id]
    player_rest = player_injuries[
        (player_injuries['report_status'].isin(['Out','Doubtful'])) &
        (player_injuries['report_primary_injury'].isin(not_injured))
    ]
    n_rest_games = len(player_rest)
    #print("\tPlayer missed game due to coach decision: ", n_rest_games)

    if n_games_available == 0:
        print(f"ERROR: Player {player_id} {player_name} hasn't played a game.")
        return "--"
    return (n_games_played + n_rest_games) / n_games_available

yrs = list(range(2009, year))
rostrs = nfl.import_weekly_rosters(yrs)
injrs = nfl.import_injuries(yrs)
print(rostrs['season'].max())
print(injrs['season'].max())
adp_full['availability'] = adp_full.apply(
    lambda row: get_availability(rostrs, injrs, py_players, row['gsis_id'], year-1),
    axis=1
)
# Out:
# 2016
# 2016.0
# ERROR: Player 00-0033856 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033280 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033893 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033923 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033897 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033908 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player 00-0033871 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033891 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033526 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033948 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033906 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033879 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0033881 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0033932 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033460 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0033951 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033925 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0033553 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player 00-0033885 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033537 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033286 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033594 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0033581 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033916 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033536 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033556 first year (2017) is before max_year (2016).
# ERROR: Player 00-0005639 last year (2009) is before 2009 so there is no data available.
# ERROR: Player 00-0033308 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033282 first year (2017) is before max_year (2016).
# ERROR: Player 00-0013688 last year (2009) is before 2009 so there is no data available.
# ERROR: Player 00-0033921 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033869 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033303 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033839 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033919 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033702 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033857 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033899 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0033288 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033293 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033561 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player 00-0033562 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033895 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033950 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player 00-0033873 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033955 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player 00-0033911 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0032870 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0033862 first year (2017) is before max_year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player 00-0031656 Kyle Brindza hasn't played a game.
# ERROR: Player 00-0033555 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033896 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033295 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033725 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033564 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033953 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033292 first year (2017) is before max_year (2016).
# ERROR: Player 00-0033858 first year (2017) is before max_year (2016).

# %% [markdown]
# Age and rookie year

# %%
def get_age(py_players, player_id):
    player = py_players[py_players['gsis_id']==player_id]
    if player.empty:
        return "D/ST"
    elif len(player)==1:
        date1 = datetime.strptime(f"{year-1}-09-01", "%Y-%m-%d")
        date2 = datetime.strptime(player['birth_date'].values[0], "%Y-%m-%d")
        delta = relativedelta(date2, date1)
        year_difference = abs(delta.years)
        return year_difference
    else:
        return "--"
    
adp_full['age'] = adp_full.apply(
    lambda row: get_age(py_players, row['gsis_id']),
    axis=1
)

def get_rookie_season(py_players, player_id):
    player = py_players[py_players['gsis_id']==player_id]
    if player.empty:
        return "D/ST"
    elif len(player)==1:
        return player['rookie_season'].values[0]
    else: 
        return "--"

adp_full['rookie_season'] = adp_full.apply(
    lambda row: get_rookie_season(py_players, row['gsis_id']),
    axis=1
)

# %% [markdown]
# Previous year snap share

# %%
def snap_share(players, ids, snap_counts, player_id, year):
    if year < 2012: 
        print(f"ERROR: year ({year}) is before the first year of snap count available (2009).")
        return -1
    player = players[players['gsis_id']==player_id]
    if player.empty:
        print(f"ERROR: Player {player_id} not found.")
        return -1
    name = player['display_name'].values[0]
    player_ids = ids[ids['gsis_id']==player_id]
    if player_ids.empty:
        print(f"ERROR: Player {player_id} ({name}) not found.")
        return -1
    pfr_id = player_ids['pfr_id'].values[0]
    snap_counts = snap_counts[snap_counts['season']==year]
    player_snaps = snap_counts[snap_counts['pfr_player_id']==pfr_id]
    if player_snaps.empty:
        print(f"ERROR: There was no data for player {player_id} ({name}) on that year ({year}).")
        return -1
    player_snaps = player_snaps[player_snaps['week'] <= 18]
    player_snaps = player_snaps[((player_snaps['season'] <= 2020) & (player_snaps['week'] <= 17)) | (player_snaps['season'] > 2020)]
    if player_snaps['position'].values[0]=='K':
        return player_snaps['st_pct'].mean()
    return player_snaps['offense_pct'].mean()

ids_players = nfl.import_ids()
snaps = nfl.import_snap_counts([year-1])
adp_full['snap_share'] = adp_full.apply(
    lambda row: snap_share(py_players, ids_players, snaps, row['gsis_id'], year-1),
    axis=1
)
# Out:
# ERROR: There was no data for player 00-0028434 (Doug Baldwin) on that year (2016).
# ERROR: There was no data for player 00-0033856 (Leonard Fournette) on that year (2016).
# ERROR: There was no data for player 00-0033280 (Christian McCaffrey) on that year (2016).
# ERROR: There was no data for player 00-0028825 (Terrelle Pryor) on that year (2016).
# ERROR: There was no data for player 00-0030656 (Isaiah Crowell) on that year (2016).
# ERROR: There was no data for player 00-0033893 (Dalvin Cook) on that year (2016).
# ERROR: There was no data for player 00-0025399 (Marshawn Lynch) on that year (2016).
# ERROR: There was no data for player 00-0033923 (Kareem Hunt) on that year (2016).
# ERROR: There was no data for player 00-0033897 (Joe Mixon) on that year (2016).
# ERROR: There was no data for player 00-0031373 (Martavis Bryant) on that year (2016).
# ERROR: There was no data for player 00-0029854 (C.J. Anderson) on that year (2016).
# ERROR: There was no data for player 00-0026019 (Danny Woodhead) on that year (2016).
# ERROR: There was no data for player 00-0027325 (LeGarrette Blount) on that year (2016).
# ERROR: There was no data for player 00-0031897 (Thomas Rawls) on that year (2016).
# ERROR: There was no data for player 00-0029597 (Justin Tucker) on that year (2016).
# ERROR: There was no data for player 00-0033908 (Cooper Kupp) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0033871 (Corey Davis) on that year (2016).
# ERROR: There was no data for player 00-0033891 (Zay Jones) on that year (2016).
# ERROR: There was no data for player 00-0033526 (Samaje Perine) on that year (2016).
# ERROR: There was no data for player 00-0033948 (Jamaal Williams) on that year (2016).
# ERROR: There was no data for player 00-0033906 (Alvin Kamara) on that year (2016).
# ERROR: There was no data for player 00-0020578 (Matt Bryant) on that year (2016).
# ERROR: There was no data for player 00-0033879 (O.J. Howard) on that year (2016).
# ERROR: There was no data for player 00-0028660 (Dan Bailey) on that year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0033881 (Evan Engram) on that year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0031228 (Taylor Gabriel) on that year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0021547 (Antonio Gates) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0016919 (Adam Vinatieri) on that year (2016).
# ERROR: There was no data for player 00-0033932 (Kenny Golladay) on that year (2016).
# ERROR: There was no data for player 00-0033460 (John Ross) on that year (2016).
# ERROR: There was no data for player 00-0023853 (Matt Prater) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0032569 (Wil Lutz) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0033951 (Marlon Mack) on that year (2016).
# ERROR: There was no data for player 00-0033925 (D'Onta Foreman) on that year (2016).
# ERROR: There was no data for player 00-0031203 (Cairo Santos) on that year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0033553 (James Conner) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0030668 (Charcandrick West) on that year (2016).
# ERROR: There was no data for player 00-0033885 (David Njoku) on that year (2016).
# ERROR: There was no data for player 00-0030821 (Allen Hurns) on that year (2016).
# ERROR: There was no data for player 00-0033537 (Deshaun Watson) on that year (2016).
# ERROR: There was no data for player 00-0033286 (Joe Williams) on that year (2016).
# ERROR: There was no data for player 00-0033594 (Chris Carson) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0031912 (Cameron Meredith) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0033581 (De'Angelo Henderson Sr.) on that year (2016).
# ERROR: There was no data for player 00-0033916 (ArDarius Stewart) on that year (2016).
# ERROR: There was no data for player 00-0031136 (Chris Boswell) on that year (2016).
# ERROR: There was no data for player 00-0033536 (Mike Williams) on that year (2016).
# ERROR: There was no data for player 00-0026858 (Graham Gano) on that year (2016).
# ERROR: There was no data for player 00-0033556 (Tarik Cohen) on that year (2016).
# ERROR: Player 00-0005639 (William Fuller) not found.
# ERROR: There was no data for player 00-0033308 (Matt Breida) on that year (2016).
# ERROR: There was no data for player 00-0030300 (Jaron Brown) on that year (2016).
# ERROR: There was no data for player 00-0031277 (Branden Oliver) on that year (2016).
# ERROR: There was no data for player 00-0033282 (Curtis Samuel) on that year (2016).
# ERROR: Player 00-0013688 (Paul Richardson) not found.
# ERROR: There was no data for player 00-0025944 (Steven Hauschka) on that year (2016).
# ERROR: There was no data for player 00-0031665 (Zach Zenner) on that year (2016).
# ERROR: There was no data for player 00-0029822 (Brandon McManus) on that year (2016).
# ERROR: There was no data for player 00-0027531 (Chris Ivory) on that year (2016).
# ERROR: There was no data for player 00-0033921 (Chris Godwin) on that year (2016).
# ERROR: There was no data for player 00-0033869 (Mitchell Trubisky) on that year (2016).
# ERROR: There was no data for player 00-0033303 (Harrison Butker) on that year (2016).
# ERROR: There was no data for player 00-0033839 (Dede Westbrook) on that year (2016).
# ERROR: There was no data for player 00-0026625 (Brian Hoyer) on that year (2016).
# ERROR: Player 00-0033919 (Carlos Henderson) not found.
# ERROR: There was no data for player 00-0033702 (Younghoe Koo) on that year (2016).
# ERROR: There was no data for player 00-0033857 (JuJu Smith-Schuster) on that year (2016).
# ERROR: There was no data for player 00-0022943 (Benjamin Watson) on that year (2016).
# ERROR: There was no data for player 00-0033899 (DeShone Kizer) on that year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0030801 (Brandon Coleman) on that year (2016).
# ERROR: There was no data for player 00-0033288 (George Kittle) on that year (2016).
# ERROR: There was no data for player 00-0032250 (Kasen Williams) on that year (2016).
# ERROR: There was no data for player 00-0033293 (Aaron Jones) on that year (2016).
# ERROR: There was no data for player 00-0030896 (Chandler Catanzaro) on that year (2016).
# ERROR: There was no data for player 00-0033561 (Donnel Pumphrey) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0029664 (Josh Gordon) on that year (2016).
# ERROR: There was no data for player 00-0031326 (Bruce Ellington) on that year (2016).
# ERROR: There was no data for player 00-0033562 (Ryan Switzer) on that year (2016).
# ERROR: There was no data for player 00-0030860 (Orleans Darkwa) on that year (2016).
# ERROR: There was no data for player 00-0029159 (Jermaine Kearse) on that year (2016).
# ERROR: There was no data for player 00-0033895 (Gerald Everett) on that year (2016).
# ERROR: There was no data for player 00-0028198 (Matt Asiata) on that year (2016).
# ERROR: There was no data for player 00-0033950 (Wayne Gallman) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0033873 (Patrick Mahomes) on that year (2016).
# ERROR: There was no data for player 00-0033955 (Jeremy McNichols) on that year (2016).
# ERROR: There was no data for player 00-0029388 (Deonte Thompson) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0031782 (Eli Rogers) on that year (2016).
# ERROR: There was no data for player 00-0033911 (Taywan Taylor) on that year (2016).
# ERROR: There was no data for player 00-0030854 (Erik Swoope) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0028497 (Kamar Aiken) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0032870 (Aldrick Rosas) on that year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0033862 (Zane Gonzalez) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0004091 (Phil Dawson) on that year (2016).
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0032087 (Josh Lambo) on that year (2016).
# ERROR: Player -- not found.
# ERROR: There was no data for player 00-0023096 (Nick Novak) on that year (2016).
# ERROR: There was no data for player 00-0027265 (Victor Cruz) on that year (2016).
# ERROR: There was no data for player 00-0031166 (Seth Roberts) on that year (2016).
# ERROR: There was no data for player 00-0028787 (Kai Forbath) on that year (2016).
# ERROR: There was no data for player 00-0028202 (Shaun Draughn) on that year (2016).
# ERROR: There was no data for player 00-0023252 (Robbie Gould) on that year (2016).
# ERROR: There was no data for player 00-0033054 (Rico Gathers) on that year (2016).
# ERROR: There was no data for player 00-0029068 (Derrick Coleman) on that year (2016).
# ERROR: Player 00-0031656 (Kyle Brindza) not found.
# ERROR: There was no data for player 00-0033555 (Mack Hollins) on that year (2016).
# ERROR: There was no data for player 00-0033896 (Adam Shaheen) on that year (2016).
# ERROR: Player 00-0031718 (Andrew Franks) not found.
# ERROR: There was no data for player 00-0026069 (Mike Tolbert) on that year (2016).
# ERROR: There was no data for player 00-0033295 (Elijah McGuire) on that year (2016).
# ERROR: There was no data for player 00-0027713 (Aaron Hernandez) on that year (2016).
# ERROR: There was no data for player 00-0033725 (Corey Clement) on that year (2016).
# ERROR: There was no data for player 00-0031900 (Rod Smith) on that year (2016).
# ERROR: There was no data for player 00-0029795 (Benny Cunningham) on that year (2016).
# ERROR: There was no data for player 00-0028263 (Andre Holmes) on that year (2016).
# ERROR: There was no data for player 00-0033564 (Jake Butt) on that year (2016).
# ERROR: There was no data for player 00-0025708 (Matt Moore) on that year (2016).
# ERROR: There was no data for player 00-0030711 (David Fluellen) on that year (2016).
# ERROR: There was no data for player 00-0033953 (Jordan Leggett) on that year (2016).
# ERROR: There was no data for player 00-0033292 (Trent Taylor) on that year (2016).
# ERROR: There was no data for player 00-0033858 (Jonnu Smith) on that year (2016).
# ERROR: There was no data for player 00-0032726 (Ka'imi Fairbairn) on that year (2016).

# %% [markdown]
# Fantasy points variance

# %%
def fan_pts_var(weekly, id, year, ppr=True):
    if year < 1999:
        print(f"ERROR: Year ({year}) must be 1999 or later.")
        return "--"
    weekly = weekly[weekly['season']== year]
    weekly = weekly[weekly['week'] >= 1]
    if year <= 2020:
        weekly = weekly[weekly['week'] <= 17]
    else:
        weekly = weekly[weekly['week'] <= 18]
    player = weekly[weekly['player_id'] == id]
    if player.empty:
        print(f"ERROR: Player with ID {id} not found in year {year}.")
        return "--"
    ppr = player['fantasy_points_ppr'].var()
    standard = player['fantasy_points'].var()
    if ppr:
        return ppr
    else:
        return standard

wd = nfl.import_weekly_data([year-1])#, downcast=True)
adp_full['fan_pts_var'] = adp_full.apply(
    lambda row: fan_pts_var(wd, row['gsis_id'], year-1),
    axis=1
)
# Out:
# Downcasting floats.
# ERROR: Player with ID 00-0033856 not found in year 2016.
# ERROR: Player with ID 00-0033280 not found in year 2016.
# ERROR: Player with ID 00-0033893 not found in year 2016.
# ERROR: Player with ID 00-0025399 not found in year 2016.
# ERROR: Player with ID 00-0033923 not found in year 2016.
# ERROR: Player with ID 00-0033897 not found in year 2016.
# ERROR: Player with ID 00-0031373 not found in year 2016.
# ERROR: Player with ID 00-0024333 not found in year 2016.
# ERROR: Player with ID 00-0033908 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0033871 not found in year 2016.
# ERROR: Player with ID 00-0033891 not found in year 2016.
# ERROR: Player with ID 00-0033526 not found in year 2016.
# ERROR: Player with ID 00-0033948 not found in year 2016.
# ERROR: Player with ID 00-0033906 not found in year 2016.
# ERROR: Player with ID 00-0020578 not found in year 2016.
# ERROR: Player with ID 00-0033879 not found in year 2016.
# ERROR: Player with ID 00-0028660 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0033881 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0025580 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0016919 not found in year 2016.
# ERROR: Player with ID 00-0033932 not found in year 2016.
# ERROR: Player with ID 00-0033460 not found in year 2016.
# ERROR: Player with ID 00-0023853 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0032569 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0033951 not found in year 2016.
# ERROR: Player with ID 00-0033925 not found in year 2016.
# ERROR: Player with ID 00-0031203 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0033553 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0019646 not found in year 2016.
# ERROR: Player with ID 00-0030098 not found in year 2016.
# ERROR: Player with ID 00-0033885 not found in year 2016.
# ERROR: Player with ID 00-0033537 not found in year 2016.
# ERROR: Player with ID 00-0033286 not found in year 2016.
# ERROR: Player with ID 00-0033594 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0029576 not found in year 2016.
# ERROR: Player with ID 00-0033581 not found in year 2016.
# ERROR: Player with ID 00-0033916 not found in year 2016.
# ERROR: Player with ID 00-0031136 not found in year 2016.
# ERROR: Player with ID 00-0033536 not found in year 2016.
# ERROR: Player with ID 00-0026858 not found in year 2016.
# ERROR: Player with ID 00-0033556 not found in year 2016.
# ERROR: Player with ID 00-0005639 not found in year 2016.
# ERROR: Player with ID 00-0033308 not found in year 2016.
# ERROR: Player with ID 00-0031277 not found in year 2016.
# ERROR: Player with ID 00-0033282 not found in year 2016.
# ERROR: Player with ID 00-0013688 not found in year 2016.
# ERROR: Player with ID 00-0025944 not found in year 2016.
# ERROR: Player with ID 00-0030390 not found in year 2016.
# ERROR: Player with ID 00-0033921 not found in year 2016.
# ERROR: Player with ID 00-0033869 not found in year 2016.
# ERROR: Player with ID 00-0033303 not found in year 2016.
# ERROR: Player with ID 00-0033839 not found in year 2016.
# ERROR: Player with ID 00-0033919 not found in year 2016.
# ERROR: Player with ID 00-0033702 not found in year 2016.
# ERROR: Player with ID 00-0033857 not found in year 2016.
# ERROR: Player with ID 00-0022943 not found in year 2016.
# ERROR: Player with ID 00-0033899 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0033288 not found in year 2016.
# ERROR: Player with ID 00-0033293 not found in year 2016.
# ERROR: Player with ID 00-0030896 not found in year 2016.
# ERROR: Player with ID 00-0033561 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0029664 not found in year 2016.
# ERROR: Player with ID 00-0031326 not found in year 2016.
# ERROR: Player with ID 00-0033562 not found in year 2016.
# ERROR: Player with ID 00-0033895 not found in year 2016.
# ERROR: Player with ID 00-0025565 not found in year 2016.
# ERROR: Player with ID 00-0033950 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0033873 not found in year 2016.
# ERROR: Player with ID 00-0033955 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0033911 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0032870 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0033862 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0004091 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0032087 not found in year 2016.
# ERROR: Player with ID -- not found in year 2016.
# ERROR: Player with ID 00-0023096 not found in year 2016.
# ERROR: Player with ID 00-0033102 not found in year 2016.
# ERROR: Player with ID 00-0026968 not found in year 2016.
# ERROR: Player with ID 00-0028787 not found in year 2016.
# ERROR: Player with ID 00-0023252 not found in year 2016.
# ERROR: Player with ID 00-0033054 not found in year 2016.
# ERROR: Player with ID 00-0029068 not found in year 2016.
# ERROR: Player with ID 00-0031656 not found in year 2016.
# ERROR: Player with ID 00-0029621 not found in year 2016.
# ERROR: Player with ID 00-0033555 not found in year 2016.
# ERROR: Player with ID 00-0033896 not found in year 2016.
# ERROR: Player with ID 00-0031718 not found in year 2016.
# ERROR: Player with ID 00-0033295 not found in year 2016.
# ERROR: Player with ID 00-0027713 not found in year 2016.
# ERROR: Player with ID 00-0033725 not found in year 2016.
# ERROR: Player with ID 00-0033564 not found in year 2016.
# ERROR: Player with ID 00-0030711 not found in year 2016.
# ERROR: Player with ID 00-0031558 not found in year 2016.
# ERROR: Player with ID 00-0033953 not found in year 2016.
# ERROR: Player with ID 00-0033292 not found in year 2016.
# ERROR: Player with ID 00-0033858 not found in year 2016.
# ERROR: Player with ID 00-0032726 not found in year 2016.

# %% [markdown]
# Cap percentage

# %%
def get_player_apy_cap_pct(name, contracts, player_id, year):
    player_cont = contracts[contracts['gsis_id']==player_id]
    if player_cont.empty:
        print(f"ERROR: did not find contracts for player {player_id} ({name})")
        return "--"
    min_year = player_cont['year_signed'].min()
    if year < min_year:
        print(f"ERROR Player ({player_id}) first contract was on {min_year}, you tried {year}.")
        return "--"
    last_contract = player_cont[player_cont['year_signed'] <= year].sort_values(by='year_signed', ascending=False).iloc[0]
    #print(last_contract[['team', 'year_signed', 'years', 'apy_cap_pct']])
    # Check if it is the active contract
    if last_contract['year_signed'] + last_contract['years'] < year:
        print(f"ERROR: Player ({player_id}) last contract ended before {year}.")
        return "--"
    return last_contract['apy_cap_pct']

conts = nfl.import_contracts()
adp_full['apt_cap_pct'] = adp_full.apply(
    lambda row: get_player_apy_cap_pct(row['Player'], conts, row['gsis_id'], year),
    axis=1
)
# Out:
# ERROR: did not find contracts for player -- (Denver Broncos)
# ERROR: did not find contracts for player -- (Seattle Seahawks)
# ERROR: did not find contracts for player -- (New York Giants)
# ERROR: did not find contracts for player -- (Kansas City Chiefs)
# ERROR: did not find contracts for player -- (Houston Texans)
# ERROR: did not find contracts for player -- (Minnesota Vikings)
# ERROR: did not find contracts for player -- (Arizona Cardinals)
# ERROR: did not find contracts for player -- (New England Patriots)
# ERROR: did not find contracts for player -- (Carolina Panthers)
# ERROR: did not find contracts for player -- (Pittsburgh Steelers)
# ERROR: did not find contracts for player -- (Jacksonville Jaguars)
# ERROR: did not find contracts for player -- (Los Angeles Rams)
# ERROR: did not find contracts for player -- (Baltimore Ravens)
# ERROR: did not find contracts for player -- (Philadelphia Eagles)
# ERROR: did not find contracts for player -- (Atlanta Falcons)
# ERROR: did not find contracts for player -- (Cincinnati Bengals)
# ERROR: did not find contracts for player -- (Los Angeles Chargers)
# ERROR: did not find contracts for player 00-0033556 (Tarik Cohen)
# ERROR: did not find contracts for player 00-0005639 (William Fuller)
# ERROR: did not find contracts for player 00-0013688 (Paul Richardson Jr.)
# ERROR: did not find contracts for player -- (Tampa Bay Buccaneers)
# ERROR: did not find contracts for player -- (Las Vegas Raiders)
# ERROR: did not find contracts for player -- (Tennessee Titans)
# ERROR: Player (00-0029664) last contract ended before 2017.
# ERROR: did not find contracts for player -- (Green Bay Packers)
# ERROR: did not find contracts for player -- (New York Jets)
# ERROR: did not find contracts for player -- (Buffalo Bills)
# ERROR: did not find contracts for player -- (Miami Dolphins)
# ERROR: did not find contracts for player -- (Dallas Cowboys)
# ERROR: did not find contracts for player -- (Cleveland Browns)
# ERROR: did not find contracts for player -- (Chicago Bears)
# ERROR: did not find contracts for player -- (San Francisco 49ers)
# ERROR: did not find contracts for player -- (Washington Commanders)
# ERROR: did not find contracts for player -- (Indianapolis Colts)
# ERROR: did not find contracts for player -- (Detroit Lions)
# ERROR: did not find contracts for player -- (New Orleans Saints)

# %% [markdown]
# Draft pick and Draft Pick value (Stuart)

# %%
def player_pick(players, player_id):
    player = players[players['gsis_id']==player_id]
    if player.empty:
        print(f"ERROR: player {player_id} not found.")
        return 
    pick = player['draft_pick'].values[0]
    return pick

def pick_value(picks, pick):
    if pd.isna(pick) or pick < 1 or pick > 262:
        return 0
    picks = nfl.import_draft_values()
    return picks[picks['pick'] == pick]['stuart'].values[0]

values = nfl.import_draft_values()
adp_full['draft_pick'] = adp_full.apply(
    lambda row: player_pick(py_players, row['gsis_id']),
    axis=1
)
adp_full['pick_value'] = adp_full.apply(
    lambda row: pick_value(values, row['draft_pick']),
    axis=1
)
# Out:
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.
# ERROR: player -- not found.

# %%
adp_full.to_csv(f"adp_full_gsispos_{year}.csv")
